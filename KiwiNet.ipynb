# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# # **KiwiNet v1.0**

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    if pred == 'kiwi bird':
      pred = 'Kiwi (flightless, nocturnal bird)'
    if pred == 'kiwi fruit':
      pred = 'Kiwifruit (Chinese Gooseberry)'
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
    btn_upload.value.clear()
    btn_upload._counter = 0

btn_run.on_click(on_click_classify)

# %%
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your kiwi!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# # **Introducing KiwiNet**
# **The Amazing Kiwi Classifier**
#
# Attention all Kiwis!
#
# Have you ever opened your mouth to bite down on a delicious **green fruit**, only to realize at the final second that you hold in your hand a **protected flightless bird**? Have you ever spent days in search of photographing the elusive **Kiwi** in the wild, only to discover after returning that you have only captured the likeness of the **Kiwifruit**?
#
# You are not alone! Cases of *mistaken identity* **abound** when it comes to the Kiwi. Far too often, unsuspecting carnivores have found themselves **forbidden from polite company** and **facing prosection** after mistakenly comsuming a **Kiwi**, rather than a **Kiwifruit** (alias *Chinese Gooseberry*). Far too often, unsuspecting bird watchers have brought **social ruin** and **expulsion from bird-watching communities** after mistaking the exterior of the **Kiwifruit** with the brown feathers of the **Kiwi**.
#
# These unhappy events may weigh on the reader's mind, but **fear not**! **KiwiNet**, the world-leading, state-of-the-art Kiwi classification tool, is here to the rescue! Utilising **modern machine learning techniques** and trained on *hundreds* of images, KiwiNet identifies Kiwi and Kiwifruit with **100% accuracy**!*
#
# **To Banish the Spectre of Mistaken Kiwi Identity Forever...**
# **Run KiwiNet Today!**
#
# *(Note: Accuracy metric is based on validation accuracy measured during modelt raining, and is for illustrative purposes only. KiwiNetCo accepts no responsibility for misclassified images)
#
# **(Note^2: The classifier only work with images of Kiwi and Kiwifruit. Inputting images of other objects might not deliver good results)

# %% [markdown]
# # **An Announcement**
#
# KiwiNet v2.0 is now under development.
#
# KiwiNet v2.0 will be able to classify to additional image types:
# 1. Kiwi Brit (*homo sapiens*)
# 2. Not Kiwi
#
# **Get excited!**
