# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# # **KiwiNet v1.0**

# %% [markdown]
# **Instructions**
#
# 1. Upload an image with the 'Upload' button.
# 2. Classify image with the 'Classify' button.
# 3. Repeat until fully satisfied.

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    if pred == 'kiwi bird':
      pred = 'Kiwi (flightless, nocturnal bird)'
    if pred == 'kiwi fruit':
      pred = 'Kiwifruit (Chinese Gooseberry)'
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
    btn_upload.value.clear()
    btn_upload._counter = 0

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Select your kiwi!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# # **Introducing KiwiNet**
# **The Amazing Kiwi Classifier**
#
# Attention all Kiwis!
#
# Have you ever opened your mouth to bite down on a delicious **green fruit**, only to realize at the final second that you hold in your hand a **protected flightless bird**? Have you ever spent days searching for an elusive **Kiwi** in the wild to photograph, only to discover after returning that you have instead captured the likeness of the **Kiwifruit**?
#
# You are not alone! Cases of *mistaken identity* **abound** when it comes to the Kiwi. Far too often, unsuspecting carnivores have found themselves **forbidden from polite company** and **facing criminal prosecution** after mistakenly comsuming a **Kiwi**, rather than a **Kiwifruit** (alias *Chinese Gooseberry*). Far too often, unsuspecting bird watchers have endured **social ruin** and **expulsion from bird-watching communities** after mistaking the exterior of the **Kiwifruit** for the brown feathers of the **Kiwi**.
#
# These unhappy events may weigh on the reader's mind, but **fear not**! **KiwiNet**, the world-leading, state-of-the-art Kiwi classification tool, is here to the rescue! Utilising **modern machine learning techniques** and trained on *hundreds* of images, KiwiNet identifies Kiwi and Kiwifruit with **100% accuracy**!*
#
# **To Banish the Spectre of Mistaken Kiwi Identity Forever...**
# **Run KiwiNet Today!**
#
# *(Note: Accuracy metric is based on validation accuracy measured during modelt raining, and is for illustrative purposes only. KiwiNet & Co accepts no responsibility for misclassified images)
#
# **(Note^2: The classifier only works with images of Kiwi and Kiwifruit. Inputting images of other objects may lead to classification error)

# %% [markdown]
# # **An Announcement**
#
# KiwiNet v2.0, featuring *even more classification types*, is now under development.
#
# We are hard at work, training KiwiNet to recognize the *elusive, mysterious* **Kiwi Brit**.
#
# **Get excited!**
